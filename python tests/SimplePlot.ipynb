# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = [22]
y = [11]
# c = [0.2,0.2,0.2, 0.5, 0.5, 0.5, 0.5, 0.5,0.5,0.5,0.8,0.8]

plt.scatter(x, y,alpha=0.5)
plt.show()

# %%
np.random.rand(N)
# Out:
# array([ 0.9171008 ,  0.73445459,  0.20761994,  0.4484164 ,  0.1332741 ,
#         0.83667338,  0.53722665,  0.92120525,  0.56073495,  0.33526462,
#         0.88046442,  0.10527269,  0.76373377,  0.39788365,  0.38458958,
#         0.99723135,  0.57996384,  0.3971904 ,  0.67144506,  0.39188705,
#         0.61440241,  0.76146413,  0.16844295,  0.72141121,  0.25455373,
#         0.80594949,  0.23141283,  0.52748995,  0.20884488,  0.5208706 ,
#         0.13491411,  0.82979191,  0.06166803,  0.21016899,  0.66051934,
#         0.05292621,  0.34783606,  0.01049958,  0.59963184,  0.63442621,
#         0.02383815,  0.25328176,  0.82042923,  0.32591134,  0.96667591,
#         0.55713795,  0.49338666,  0.37192782,  0.18570197,  0.50426539])
